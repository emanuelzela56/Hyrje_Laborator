# %% [markdown]
# ## Laboratori 02 – Struktura e Raportit dhe Markdown
#
# **Studenti:** *Emanuel Zela*
# **Data:** *2026-03-18*

# %% [markdown]
# ---

# %% [markdown]
# ## Qëllimi
#
# 1. Te praktikoni shkrimin profesional në **Markdown**.
# 2. Te perdorni **formula matematikore (LaTeX)**.
# 3. Te ndertoni **strukturen standarde** te raportit laboratorik ne notebook.

# %% [markdown]
# ## 1. Titulli dhe Qellimi
#
# Shkruani objektivin e eksperimentit (2–4 fjali).
# **Shembull:** "Te matet diametri i një cilindri me mjete të ndryshme dhe të vlerësohet pasiguria e matjes."
#
# **Qellimi:**
# Te matet diametri i nje cilindri me mjete te ndryshe ne menyre qe te gjindet gabimi me i vogel i mundshem.

# %% [markdown]
# ## 2. Baza teorike
#
# Shkruani formulat dhe shpjegoni simbolet.
#
# **Shembull (vellimi i cilindrit):**
#
# $$
# V = \pi r^2 h
# $$
#
# ku:
# - $r$ – rrezja (m)
# - $h$ – lartesia (m)
# - $V$ – vellimi (m$^3$)

# %% [markdown]
# **Teoria (plotesoni):**
#
# $$
# r = \frac{d}{2}
# $$
#
# Nese objekti eshte cilinder, vellimi i tij jepet nga:
#
# $$
# V = \pi r^2 h
# $$
#
# ku:
# - $r$ – rrezja (m)
# - $h$ – lartësia (m)
# - $V$ – vëllimi (m$^3$)
#
# Matjet eksperimentale kane gjithmone pasiguri.
# Vlera mesatare llogaritet si:
#
# $$
# \bar{x} = \frac{1}{n} \sum x_i
# $$
#
# Qellimi eshte te merret nje vlere sa me e sakte duke perdorur disa matje dhe duke reduktuar gabimet.

# %% [markdown]
# # 3. Aparatura dhe Procedura

# %% [markdown]
# # 4. Te dhenat Bruto
