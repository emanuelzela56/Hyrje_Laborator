# %% [markdown]
# # Laboratori 01 – Hyrje ne JupyterLab dhe Mjedisin e Punes
#
# **Kursi:** Hyrje ne laborator (Fizike & Shkenca Kompjuterike)
# **Studenti:** *Emanuel Zela*
# **Data:** *2026-03-11*
#
# ---
#
# ## Qellimi
#
# Ne kete notebook do te dokumentoni:
#
# 1. Konfigurimin e "environment" `lab` (Conda).
# 2. Nisjen e JupyterLab dhe krijimin e notebook-ut.
# 3. Ekzekutimin e qelizave (cells) dhe kontrollin baze te kernel-it.
# 4. Nje test minimal te funksionimit te Python/NumPy/Matplotlib.
#
# ---
#
# ## Lista e kontrollit (Checklist)
#
# - y = yes
# - n = no
# - [y] Miniconda/Anaconda i instaluar
# - [y] Mjedisi `lab` i krijuar
# - [y] JupyterLab nis pa probleme
# - [y] Qelizat e kodit ekzekutohen (Shift+Enter)
# - [y] Notebook-u ruhet dhe ngarkohet ne GitHub
#
# ---
#
# ## 1. Komandat e instalimit
#
# ### Linux/macOS
#
# ```bash
# conda create -n lab python=3.11
# conda activate lab
# conda install jupyterlab numpy scipy pandas matplotlib
# jupyter-lab

# %% [markdown]
# # 2. Rregull Pune
# Para dorezimit:
# 1. **Kernel** &rarr; **Restart Kernel**
# 2. **Run** &rarr; **Run all Cells**
# 3. Sigurohuni qe **nuk ka gabime**
# 4. Ruani notebook-un (**Ctrl+S**)

# %% [markdown]
# # 3. Perfundim
# + A funksionoi instalimi?
# + A u hap JupyterLab pa probleme?
# + A pati ndonje gabim qe u desh te zgjidhnit?
# + A e kuptoni dallimin mes qelizave **Markdown** dhe **Code**?

# %% [markdown]
# ## Pergjigje:
#
# + Po instalimi funksionoi.
# + JupyterLab u hap pa probleme.
# + Asnje gabim qe nevojitej te zgjidhej.
# + Dallimi mes qelizave **Markdown** dhe **Code** eshte i qarte.
